# %%
import pandas as ps
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
df =sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# find all the first clas pessenger
# using pandas filter
# using panda query function

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
ffirst =df['class'] == 'First'
df[ffirst]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 11          1       1  female  58.0      0      0  26.5500        S  First
# 23          1       1    male  28.0      0      0  35.5000        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 11   woman       False    C  Southampton   yes   True
# 23     man        True    A  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [216 rows x 15 columns]

# %%
filterage20 =df['age'] <=20
df[filterage20]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 12          0       3    male  20.0      0      0   8.0500        S   Third
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 869         1       3    male   4.0      1      1  11.1333        S   Third
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 876         0       3    male  20.0      0      0   9.8458        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# 7    child       False  NaN  Southampton    no  False
# 9    child       False  NaN    Cherbourg   yes  False
# 10   child       False    G  Southampton   yes  False
# 12     man        True  NaN  Southampton    no   True
# 14   child       False  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 869  child       False  NaN  Southampton   yes  False
# 875  child       False  NaN    Cherbourg   yes   True
# 876    man        True  NaN  Southampton    no   True
# 877    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
#
# [179 rows x 15 columns]

# %%
df[filterage20 & ffirst]
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked  class  \
# 27          0       1    male  19.00      3      2  263.0000        S  First
# 136         1       1  female  19.00      0      2   26.2833        S  First
# 291         1       1  female  19.00      1      0   91.0792        C  First
# 297         0       1  female   2.00      1      2  151.5500        S  First
# 305         1       1    male   0.92      1      2  151.5500        S  First
# 307         1       1  female  17.00      1      0  108.9000        C  First
# 311         1       1  female  18.00      2      2  262.3750        C  First
# 329         1       1  female  16.00      0      1   57.9792        C  First
# 435         1       1  female  14.00      1      2  120.0000        S  First
# 445         1       1    male   4.00      0      2   81.8583        S  First
# 504         1       1  female  16.00      0      0   86.5000        S  First
# 505         0       1    male  18.00      1      0  108.9000        C  First
# 550         1       1    male  17.00      0      2  110.8833        C  First
# 585         1       1  female  18.00      0      2   79.6500        S  First
# 689         1       1  female  15.00      0      1  211.3375        S  First
# 700         1       1  female  18.00      1      0  227.5250        C  First
# 748         0       1    male  19.00      1      0   53.1000        S  First
# 781         1       1  female  17.00      1      0   57.0000        S  First
# 802         1       1    male  11.00      1      2  120.0000        S  First
# 853         1       1  female  16.00      0      1   39.4000        S  First
# 887         1       1  female  19.00      0      0   30.0000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 27     man        True    C  Southampton    no  False
# 136  woman       False    D  Southampton   yes  False
# 291  woman       False    B    Cherbourg   yes  False
# 297  child       False    C  Southampton    no  False
# 305  child       False    C  Southampton   yes  False
# 307  woman       False    C    Cherbourg   yes  False
# 311  woman       False    B    Cherbourg   yes  False
# 329  woman       False    B    Cherbourg   yes  False
# 435  child       False    B  Southampton   yes  False
# 445  child       False    A  Southampton   yes  False
# 504  woman       False    B  Southampton   yes   True
# 505    man        True    C    Cherbourg    no  False
# 550    man        True    C    Cherbourg   yes  False
# 585  woman       False    E  Southampton   yes  False
# 689  child       False    B  Southampton   yes  False
# 700  woman       False    C    Cherbourg   yes  False
# 748    man        True    D  Southampton    no  False
# 781  woman       False    B  Southampton   yes  False
# 802  child       False    B  Southampton   yes  False
# 853  woman       False    D  Southampton   yes  False
# 887  woman       False    B  Southampton   yes   True

# %%
df[filterage20 & ~ffirst]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 12          0       3    male  20.0      0      0   8.0500        S   Third
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 855         1       3  female  18.0      0      1   9.3500        S   Third
# 869         1       3    male   4.0      1      1  11.1333        S   Third
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 876         0       3    male  20.0      0      0   9.8458        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 7    child       False  NaN  Southampton    no  False
# 9    child       False  NaN    Cherbourg   yes  False
# 10   child       False    G  Southampton   yes  False
# 12     man        True  NaN  Southampton    no   True
# 14   child       False  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 855  woman       False  NaN  Southampton   yes  False
# 869  child       False  NaN  Southampton   yes  False
# 875  child       False  NaN    Cherbourg   yes   True
# 876    man        True  NaN  Southampton    no   True
# 877    man        True  NaN  Southampton    no   True
#
# [158 rows x 15 columns]

# %%
filterage60 =df['age'] == 60
df[filterage60]
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 366         1       1  female  60.0      1      0  75.25        C   First
# 587         1       1    male  60.0      1      1  79.20        C   First
# 684         0       2    male  60.0      1      1  39.00        S  Second
# 694         0       1    male  60.0      0      0  26.55        S   First
#
#        who  adult_male deck  embark_town alive  alone
# 366  woman       False    D    Cherbourg   yes  False
# 587    man        True    B    Cherbourg   yes  False
# 684    man        True  NaN  Southampton    no  False
# 694    man        True  NaN  Southampton    no   True

# %%
fthird =df['class'] == 'Third'
df[fthird]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# 5           0       3    male   NaN      0      0   8.4583        Q  Third
# 7           0       3    male   2.0      3      1  21.0750        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 882         0       3  female  22.0      0      0  10.5167        S  Third
# 884         0       3    male  25.0      0      0   7.0500        S  Third
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 2    woman       False  NaN  Southampton   yes   True
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 7    child       False  NaN  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 882  woman       False  NaN  Southampton    no   True
# 884    man        True  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 888  woman       False  NaN  Southampton    no  False
# 890    man        True  NaN   Queenstown    no   True
#
# [491 rows x 15 columns]

# %%
df[filterage60 & fthird]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %%
df.query('age <=20')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 12          0       3    male  20.0      0      0   8.0500        S   Third
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 869         1       3    male   4.0      1      1  11.1333        S   Third
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 876         0       3    male  20.0      0      0   9.8458        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# 7    child       False  NaN  Southampton    no  False
# 9    child       False  NaN    Cherbourg   yes  False
# 10   child       False    G  Southampton   yes  False
# 12     man        True  NaN  Southampton    no   True
# 14   child       False  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 869  child       False  NaN  Southampton   yes  False
# 875  child       False  NaN    Cherbourg   yes   True
# 876    man        True  NaN  Southampton    no   True
# 877    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
#
# [179 rows x 15 columns]

# %% [markdown]
# #group by
#
# column to group data (categorical)
# output column to display(optional)
# aggregation function (required)
#     - mean ,sum , max, min, std,count
#
#
# df,group('column')[col_to_out].sum()

# %%
df.groupby('embark_town').sum()
# Out:
#              survived  pclass       age  sibsp  parch        fare  adult_male  \
# embark_town
# Cherbourg          93     317   4005.92     65     61  10072.2962          90
# Queenstown         30     224    786.50     33     13   1022.2543          37
# Southampton       217    1514  16312.75    368    266  17439.3988         410
#
#              alone
# embark_town
# Cherbourg       85
# Queenstown      57
# Southampton    393

# %%
df.groupby('embark_town')['age'].mean()
# Out:
# embark_town
# Cherbourg      30.814769
# Queenstown     28.089286
# Southampton    29.445397
# Name: age, dtype: float64

# %%
df.groupby('embark_town')['survived'].sum()
# Out:
# embark_town
# Cherbourg       93
# Queenstown      30
# Southampton    217
# Name: survived, dtype: int64

# %%
df.groupby('embark_town')['survived'].agg(['sum','mean','std','count'])
# Out:
#              sum      mean       std  count
# embark_town
# Cherbourg     93  0.553571  0.498608    168
# Queenstown    30  0.389610  0.490860     77
# Southampton  217  0.336957  0.473037    644

# %%
df.groupby('embark_town')['survived'].agg(['sum','count']).plot(title ='Survivors' , kind ='barh')
# Out:
# <AxesSubplot:title={'center':'Survivors'}, ylabel='embark_town'>

# %%
df.groupby(['embark_town','who'])['survived'].sum().reset_index().style.bar('survived')
# Out:
# <style type="text/css">
# #T_e99f9_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.3%, transparent 11.3%);
# }
# #T_e99f9_row1_col2, #T_e99f9_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.0%, transparent 21.0%);
# }
# #T_e99f9_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 42.7%, transparent 42.7%);
# }
# #T_e99f9_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.8%, transparent 0.8%);
# }
# #T_e99f9_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.4%, transparent 2.4%);
# }
# #T_e99f9_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 27.4%, transparent 27.4%);
# }
# #T_e99f9_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 47.6%, transparent 47.6%);
# }
# #T_e99f9_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_e99f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e99f9_level0_col0" class="col_heading level0 col0" >embark_town</th>
#       <th id="T_e99f9_level0_col1" class="col_heading level0 col1" >who</th>
#       <th id="T_e99f9_level0_col2" class="col_heading level0 col2" >survived</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e99f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e99f9_row0_col0" class="data row0 col0" >Cherbourg</td>
#       <td id="T_e99f9_row0_col1" class="data row0 col1" >child</td>
#       <td id="T_e99f9_row0_col2" class="data row0 col2" >14</td>
#     </tr>
#     <tr>
#       <th id="T_e99f9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e99f9_row1_col0" class="data row1 col0" >Cherbourg</td>
#       <td id="T_e99f9_row1_col1" class="data row1 col1" >man</td>
#       <td id="T_e99f9_row1_col2" class="data row1 col2" >26</td>
#     </tr>
#     <tr>
#       <th id="T_e99f9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e99f9_row2_col0" class="data row2 col0" >Cherbourg</td>
#       <td id="T_e99f9_row2_col1" class="data row2 col1" >woman</td>
#       <td id="T_e99f9_row2_col2" class="data row2 col2" >53</td>
#     </tr>
#     <tr>
#       <th id="T_e99f9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e99f9_row3_col0" class="data row3 col0" >Queenstown</td>
#       <td id="T_e99f9_row3_col1" class="data row3 col1" >child</td>
#       <td id="T_e99f9_row3_col2" class="data row3 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e99f9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e99f9_row4_col0" class="data row4 col0" >Queenstown</td>
#       <td id="T_e99f9_row4_col1" class="data row4 col1" >man</td>
#       <td id="T_e99f9_row4_col2" class="data row4 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e99f9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e99f9_row5_col0" class="data row5 col0" >Queenstown</td>
#       <td id="T_e99f9_row5_col1" class="data row5 col1" >woman</td>
#       <td id="T_e99f9_row5_col2" class="data row5 col2" >26</td>
#     </tr>
#     <tr>
#       <th id="T_e99f9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e99f9_row6_col0" class="data row6 col0" >Southampton</td>
#       <td id="T_e99f9_row6_col1" class="data row6 col1" >child</td>
#       <td id="T_e99f9_row6_col2" class="data row6 col2" >34</td>
#     </tr>
#     <tr>
#       <th id="T_e99f9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e99f9_row7_col0" class="data row7 col0" >Southampton</td>
#       <td id="T_e99f9_row7_col1" class="data row7 col1" >man</td>
#       <td id="T_e99f9_row7_col2" class="data row7 col2" >59</td>
#     </tr>
#     <tr>
#       <th id="T_e99f9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e99f9_row8_col0" class="data row8 col0" >Southampton</td>
#       <td id="T_e99f9_row8_col1" class="data row8 col1" >woman</td>
#       <td id="T_e99f9_row8_col2" class="data row8 col2" >124</td>
#     </tr>
#   </tbody>
# </table>
