# %%
import numpy as np 
import matplotlib.pyplot as plt #image plotting
import seaborn as sns #statistical data visualization
import plotly.express as px # data visualization

# %%
data = np.random.randint(0,100,50)
print(data)
# Out:
# [17 38  1 57  6 69 93 89 15 58 21 57 77 38 13 17 41  1  5 96 77 24 99 55
#  93 36  9 37  3 89 45 41 26 35 41 28 46 39 72 87 73 87 80 66 23 67 55  1
#   9 15]

# %%
plt.figure(figsize = (25,5))
plt.plot(data)

# %%
plt.figure(figsize = (25,5))
plt.plot(data,color ='red',linestyle = ':')

# %%
plt.figure(figsize = (25,5))
plt.plot(data,color ='red',linewidth =3,linestyle =':',marker='*',markersize =10)

# %%
plt.figure(figsize = (25,5))
plt.plot(data,'g--x')

# %%
plt.figure(figsize = (25,5) , facecolor ='yellow')
plt.plot(data, 'g--x')
plt.title("simple line plot demo" , fontsize =20, color ='black' , fontdict = {'family' : 'cosmic'})
plt.xlabel("x axis data" , fontsize =30)
plt.ylabel("y axis data" , fontsize =30)
# Out:
# Text(0, 0.5, 'y axis data')
# findfont: Font family ['cosmic'] not found. Falling back to DejaVu Sans.
